# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/UK dataset ")

# %%
df
# Out:
#          Unnamed: 0 Accident_Index  Location_Easting_OSGR  \
# 0                 0  200501BS00001               525680.0
# 1                 1  200501BS00002               524170.0
# 2                 2  200501BS00003               524520.0
# 3                 3  200501BS00004               526900.0
# 4                 4  200501BS00005               528060.0
# ...             ...            ...                    ...
# 1504145      464692       2.01E+12               310037.0
# 1504146      464693       2.01E+12               321509.0
# 1504147      464694       2.01E+12               321337.0
# 1504148      464695       2.01E+12               323869.0
# 1504149      464696       2.01E+12               314072.0
#
#          Location_Northing_OSGR  Longitude   Latitude  Police_Force  \
# 0                      178240.0  -0.191170  51.489096             1
# 1                      181650.0  -0.211708  51.520075             1
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0           0  200501BS00001               525680.0                178240.0
# 1           1  200501BS00002               524170.0                181650.0
# 2           2  200501BS00003               524520.0                182240.0
# 3           3  200501BS00004               526900.0                177530.0
# 4           4  200501BS00005               528060.0                179040.0
#
#    Longitude   Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  -0.191170  51.489096             1                  2                   1
# 1  -0.211708  51.520075             1                  3                   1
# 2  -0.206458  51.525301             1                  3                   2
# 3  -0.173862  51.482442             1                  3                   1
# 4  -0.156618  51.495752             1                  3                   1
#
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  Location_Easting_OSGR  Location_Northing_OSGR  \
# count  1.504150e+06           1.504049e+06            1.504150e+06
# mean   2.530433e+05           4.396214e+05            3.001382e+05
# std    1.489162e+05           9.511616e+04            1.610218e+05
# min    0.000000e+00           6.495000e+04            0.000000e+00
# 25%    1.253452e+05           3.750600e+05            1.782600e+05
# 50%    2.506910e+05           4.399600e+05            2.688000e+05
# 75%    3.760370e+05           5.230600e+05            3.981500e+05
# max    5.700100e+05           6.553700e+05            1.208800e+06
#
#           Longitude      Latitude  Police_Force  Accident_Severity  \
# count  1.504049e+06  1.504150e+06  1.504150e+06       1.504150e+06
# mean  -1.436625e+00  5.258587e+01  3.020536e+01       2.838190e+00
# std    1.398078e+00  1.512524e+00  2.551603e+01       4.018423e-01
# min   -7.516225e+00  0.000000e+00  1.000000e+00       1.000000e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1504150 entries, 0 to 1504149
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Unnamed: 0                                   1504150 non-null  int64
#  1   Accident_Index                               1504150 non-null  object
#  2   Location_Easting_OSGR                        1504049 non-null  float64
#  3   Location_Northing_OSGR                       1504150 non-null  float64
#  4   Longitude                                    1504049 non-null  float64
#  5   Latitude                                     1504150 non-null  float64
#  6   Police_Force                                 1504150 non-null  int64
#  7   Accident_Severity                            1504150 non-null  int64
#  8   Number_of_Vehicles                           1504150 non-null  int64
# ...

# %%
X = df.drop("Accident_Severity",  axis=1)
y = df["Accident_Severity"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
X_train.shape, X_test.shape
# Out:
# ((1007780, 32), (496370, 32))

# %%
X_train.dtypes
# Out:
# Unnamed: 0                                       int64
# Accident_Index                                  object
# Location_Easting_OSGR                          float64
# Location_Northing_OSGR                         float64
# Longitude                                      float64
# Latitude                                       float64
# Police_Force                                     int64
# Number_of_Vehicles                               int64
# Number_of_Casualties                             int64
# Date                                            object
# Day_of_Week                                      int64
# Time                                            object
# Local_Authority_(District)                       int64
# Local_Authority_(Highway)                       object
# 1st_Road_Class                                   int64
# 1st_Road_Number                                  int64
# Road_Type                                       object
# ...

# %%
X_train.head()
# Out:
#          Unnamed: 0 Accident_Index  Location_Easting_OSGR  \
# 717579       147568    2.00961E+12               328210.0
# 739685       169674  201001JC30117               536630.0
# 1292511      253058  201332N262413               487415.0
# 596871        26860  200904CL09041               352490.0
# 1218517      179064  201297UC01511               242680.0
#
#          Location_Northing_OSGR  Longitude   Latitude  Police_Force  \
# 717579                 200430.0  -3.040173  51.697962            61
# 739685                 188210.0  -0.029682  51.576151             1
# 1292511                353979.0  -0.696596  53.075877            32
# 596871                 422920.0  -2.721121  53.700538             4
# 1218517                635860.0  -4.497968  55.590923            97
#
#          Number_of_Vehicles  Number_of_Casualties        Date  ...  \
# 717579                    3                     1  21/04/2009  ...
# 739685                    2                     1  02/01/2010  ...
# ...

# %%
X_test.head()
# Out:
#          Unnamed: 0 Accident_Index  Location_Easting_OSGR  \
# 294815       294815  20063102D0279               460210.0
# 603898        33887  200906B023849               384700.0
# 682956       112945  200943W220129               481850.0
# 1150698      111245  201232N036612               506620.0
# 711462       141451    2.00953E+12               385160.0
#
#          Location_Northing_OSGR  Longitude   Latitude  Police_Force  \
# 294815                 345330.0  -1.104237  53.001892            31
# 603898                 395130.0  -2.231870  53.452693             6
# 682956                 168770.0  -0.824485  51.411999            43
# 1150698                358600.0  -0.408496  53.113915            32
# 711462                 189050.0  -2.215673  51.600046            53
#
#          Number_of_Vehicles  Number_of_Casualties        Date  ...  \
# 294815                    2                     1  07/02/2006  ...
# 603898                    2                     1  04/11/2009  ...
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
plt.figure(figsize=(10,7))
plt.pie(x=df['Accident_Severity'].value_counts().values,
        labels=df['Accident_Severity'].value_counts().index,
        autopct='%2.2f%%')
plt.show()

# %%
sns.boxplot(x=df['Accident_Severity'], y=df['Speed_limit'])
plt.show()

# %%
df_for_histplot =df[
    df["Special_Conditions_at_Site"] != "None"
][df["Pedestrian_Crossing-Human_Control"] != "None within 50 metres"]
sns.histplot(
    x=df_for_histplot["Special_Conditions_at_Site"],
    hue=df_for_histplot["Pedestrian_Crossing-Human_Control"],
    multiple="stack",
    stat="count",
    binwidth=0.5,
)
plt.xticks(rotation=90)
# Out:
# <ipython-input-84-846945393b0c>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_for_histplot =df[
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Roadworks'),
#   Text(1, 0, 'Auto traffic singal out'),
#   Text(2, 0, 'Ol or diesel'),
#   Text(3, 0, 'Auto traffic signal partly defective'),
#   Text(4, 0, 'Permanent sign or marking defective or obscured'),
#   Text(5, 0, 'Road surface defective'),
#   Text(6, 0, 'Mud')])

# %%
COLUMNS_USED = [
    "Accident_Severity",
    "Day_of_Week",
    "Road_Type",
    "Speed_limit",
    "Light_Conditions",
    "Weather_Conditions",
    "Road_Surface_Conditions",
    "Junction_Control",
    "1st_Road_Class",
    "Carriageway_Hazards",
    "Special_Conditions_at_Site",
    "Urban_or_Rural_Area",
    "Pedestrian_Crossing-Human_Control",
    "Pedestrian_Crossing-Physical_Facilities",
]
accident_data = df[COLUMNS_USED].copy()

# %%
df.isna().sum()
# Out:
# Unnamed: 0                                          0
# Accident_Index                                      0
# Location_Easting_OSGR                             101
# Location_Northing_OSGR                              0
# Longitude                                         101
# Latitude                                            0
# Police_Force                                        0
# Accident_Severity                                   0
# Number_of_Vehicles                                  0
# Number_of_Casualties                                0
# Date                                                0
# Day_of_Week                                         0
# Time                                              117
# Local_Authority_(District)                          0
# Local_Authority_(Highway)                           0
# 1st_Road_Class                                      0
# 1st_Road_Number                                     0
# ...

# %%
df.describe(include="all")
# Out:
#           Unnamed: 0 Accident_Index  Location_Easting_OSGR  \
# count   1.504150e+06        1504150           1.504049e+06
# unique           NaN         927387                    NaN
# top              NaN       2.01E+12                    NaN
# freq             NaN         381416                    NaN
# mean    2.530433e+05            NaN           4.396214e+05
# std     1.489162e+05            NaN           9.511616e+04
# min     0.000000e+00            NaN           6.495000e+04
# 25%     1.253452e+05            NaN           3.750600e+05
# 50%     2.506910e+05            NaN           4.399600e+05
# 75%     3.760370e+05            NaN           5.230600e+05
# max     5.700100e+05            NaN           6.553700e+05
#
#         Location_Northing_OSGR     Longitude      Latitude  Police_Force  \
# count             1.504150e+06  1.504049e+06  1.504150e+06  1.504150e+06
# unique                     NaN           NaN           NaN           NaN
# ...

# %%
df['Accident_Severity'].value_counts()
# Out:
# 3    1280205
# 2     204504
# 1      19441
# Name: Accident_Severity, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
x = df['Longitude'].values
y = df['Latitude'].values
x = x.reshape(-1,1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
x_train.shape
# Out:
# (1128112, 1)

# %%
x_test.shape
# Out:
# (376038, 1)

# %%
columns=non_numeric_columns = df.select_dtypes(exclude=['object'])

# Create histplot for each column
for column in columns:
    sns.histplot(data=df, x=column)
    plt.title(f'Histogram of {column.capitalize()}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
x=df['Accident_Severity']
plt.hist(x)
plt.show()

# %%
finalDf = df[[c for c in df if c not in ['Accident_Severity']]
       + ['Accident_Severity']]

# %%
finalDf
# Out:
#          Unnamed: 0 Accident_Index  Location_Easting_OSGR  \
# 0                 0  200501BS00001               525680.0
# 1                 1  200501BS00002               524170.0
# 2                 2  200501BS00003               524520.0
# 3                 3  200501BS00004               526900.0
# 4                 4  200501BS00005               528060.0
# ...             ...            ...                    ...
# 1504145      464692       2.01E+12               310037.0
# 1504146      464693       2.01E+12               321509.0
# 1504147      464694       2.01E+12               321337.0
# 1504148      464695       2.01E+12               323869.0
# 1504149      464696       2.01E+12               314072.0
#
#          Location_Northing_OSGR  Longitude   Latitude  Police_Force  \
# 0                      178240.0  -0.191170  51.489096             1
# 1                      181650.0  -0.211708  51.520075             1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %%
model=RandomForestClassifier()

# %%
x_train
# Out:
# array([[-2.700171],
#        [-1.994651],
#        [-3.15864 ],
#        ...,
#        [-1.732084],
#        [-2.931723],
#        [-0.476218]])

# %%
x_test
# Out:
# array([[-4.866962],
#        [-1.129347],
#        [-3.03528 ],
#        ...,
#        [-1.207408],
#        [-0.128465],
#        [ 0.194183]])

# %%
y_test
# Out:
# array([50.56186 , 52.634302, 51.565826, ..., 51.751091, 51.310592,
#        52.78568 ])

# %%
y_train
# Out:
# array([52.705644, 52.608103, 51.468782, ..., 51.437729, 56.487956,
#        51.537029])

# %%
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %%
model=RandomForestClassifier()

# %%
from sklearn.linear_model import LogisticRegression

# %%
df['Did_Police_Officer_Attend_Scene_of_Accident'] = pd.to_numeric(df['Date'], errors='coerce')

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                                           0
# Accident_Index                                       0
# Location_Easting_OSGR                              101
# Location_Northing_OSGR                               0
# Longitude                                          101
# Latitude                                             0
# Police_Force                                         0
# Accident_Severity                                    0
# Number_of_Vehicles                                   0
# Number_of_Casualties                                 0
# Date                                                 0
# Day_of_Week                                          0
# Time                                               117
# Local_Authority_(District)                           0
# Local_Authority_(Highway)                            0
# 1st_Road_Class                                       0
# 1st_Road_Number                                      0
# ...
